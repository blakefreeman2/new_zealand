# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
import matplotlib.pyplot as plt

# %%
# Yelp API Keys
from nconfig import naveenkey
from sconfig import sindhu_api
from config import yelp_api_matt
from config import yelp_api

# %%
#Auckland Active life pull
def active_life(set_num): 

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {naveenkey}",}
    url_params = {
    "categories" : "active, All",
    "location" : "Auckland",
    "offset" : offset_num,
    "limit" : 50}

    response = requests.get(url, headers = headers, params = url_params)
    return response.json()

for offset_num in np.arange(50,400,50) : 
    try:
        output_json = active_life(offset_num)
        #pprint(offset_num) 
        #pprint(output_json)
        if offset_num == 50:
            df1a = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2a = pd.DataFrame.from_dict(output_json['businesses'])
            df1a = df1a.append(df2a)
    except AttributeError:
        pprint("error at ", offset_num)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
#Auckland_restaurants
def Auckland_restaurants(set_num):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {yelp_api}",
    }
    url_params = {
        "categories" : "restaurants, All",
        "location" : "Auckland",
        "offset" : offset_num,
        "limit" : 50}
    
    response_auck_rest = requests.get(url, headers = headers, params = url_params)
    return response_auck_rest.json()


for offset_num in np.arange(50,1000,50) :
    try:
        output_json = Auckland_restaurants(offset_num)
        #pprint(offset_num)
        #pprint(output_json)
        if offset_num == 50:
            df_Auckland_restaurants = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2 = pd.DataFrame.from_dict(output_json['businesses'])
            df_Auckland_restaurants = df_Auckland_restaurants.append(df2)
    except AttributeError:
           print("error at ", offset_num)

# %%
#Auckland Shoppingcenter
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {sindhu_api}",}
url_params_wel = {"term" : "shopping centers","location" : "Auckland"}

response_auck = requests.get(url, headers=headers, params=url_params_wel)
auck_data = response_auck.json()
#pprint(auck_data)
df_auckland_shopping = pd.DataFrame.from_dict(auck_data['businesses'])

# %%
#Auckland hotel pull
def aucklandhotel(set_num): 

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {yelp_api_matt}",}
    url_params = {
    "term" : "hotel",
    "location" : "Auckland",
    "offset" : offset_num,
    "limit" : 50}

    response_auck_hotel = requests.get(url, headers = headers, params = url_params)
    return response_auck_hotel.json()

for offset_num in np.arange(50,1000,50) : 
    try:
        output_json = aucklandhotel(offset_num)
        #pprint(offset_num) 
        #pprint(output_json)
        if offset_num == 50:
            df_hotel_auk = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2ah = pd.DataFrame.from_dict(output_json['businesses'])
            df_hotel_auk = df_hotel_auk.append(df2ah)
    except AttributeError:
        pprint("error at ", offset_num)

# %%
#Wellington Active life pull
def active_life(set_num): 

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {naveenkey}",}
    url_params = {
    "categories" : "active, All",
    "location" : "Wellington",
    "offset" : offset_num,
    "limit" : 50}

    response = requests.get(url, headers = headers, params = url_params)
    return response.json()

for offset_num in np.arange(50,200,50) : 
    try:
        output_json = active_life(offset_num)
        #pprint(offset_num) 
        #pprint(output_json)
        if offset_num == 50:
            df1w = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2w = pd.DataFrame.from_dict(output_json['businesses'])
            df1w = df1w.append(df2w)
    except AttributeError:
        pprint("error at ", offset_num)

# %%
#Wellington restaurants pull
def Wellington_restaurants(set_num):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {yelp_api}",
    }
    url_params = {
        "categories" : "restaurants, All",
        "location" : "Wellington",
        "offset" : offset_num,
        "limit" : 50}
    response = requests.get(url, headers = headers, params = url_params)
    return response.json()


for offset_num in np.arange(50,1000,50) :
    try:
        output_json = Wellington_restaurants(offset_num)
        #pprint(offset_num)
        #pprint(output_json)
        if offset_num == 50:
            df_Wellington_restaurants = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2 = pd.DataFrame.from_dict(output_json['businesses'])
            df_Wellington_restaurants = df_Wellington_restaurants.append(df2)
    except AttributeError:
           print("error at ", offset_num)

# %%
#Wellington Shoppingcenter
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {sindhu_api}",}
url_params_well = {"term" : "shopping centers","location" : "Wellington"}

response_well = requests.get(url, headers=headers, params=url_params_well)
well_data = response_well.json()
#pprint(well_data)
df_wellington_shopping = pd.DataFrame.from_dict(auck_data['businesses'])

# %%
#Wellington Hotel
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {yelp_api_matt}",}
url_params_wel = {"categories" : "hotels, ALL","location" : "Wellington"}

response_wel = requests.get(url, headers=headers, params=url_params_wel)
wel_data = response_wel.json()
#pprint(wel_data)
df_hotel_wel = pd.DataFrame(wel_data['businesses'])

# %%
#Christchurch Active life pull
def active_life(set_num): 

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {naveenkey}",}
    url_params = {
    "categories" : "active, All",
    "location" : "Christchurch",
    "offset" : offset_num,
    "limit" : 50}

    response = requests.get(url, headers = headers, params = url_params)
    return response.json()

for offset_num in np.arange(5,30,5): 
    try:
        output_json = active_life(offset_num)
        #pprint(offset_num) 
        #pprint(output_json)
        if offset_num == 5:
            df1c = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2c = pd.DataFrame.from_dict(output_json['businesses'])
            df1c = df1c.append(df2c)
    except AttributeError:
        pprint("error at ", offset_num)

# %%
#Christchurch_restaurants
def Christchurch_restaurants(set_num):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {yelp_api}",
    }
    url_params = {
        "categories" : "restaurants, All",
        "location" : "Christchurch",
        "offset" : offset_num,
        "limit" : 50}
    response = requests.get(url, headers = headers, params = url_params)
    return response.json()


for offset_num in np.arange(50,1000,50) :
    try:
        output_json = Christchurch_restaurants(offset_num)
        #pprint(offset_num)
        #pprint(output_json)
        if offset_num == 50:
            df_Christchurch_restaurants = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2 = pd.DataFrame.from_dict(output_json['businesses'])
            df_Christchurch_restaurants = df_Christchurch_restaurants.append(df2)
    except AttributeError:
           print("error at ", offset_num)

# %%
#Christchurch Shoppingcenter
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {sindhu_api}",}
url_params_christ = {"term" : "shopping centers","location" : "Christchurch","limit" : 50}

response_christ = requests.get(url, headers=headers, params=url_params_christ)
christ_data = response_christ.json()
#pprint(christ_data)
df_christchurch_shopping = pd.DataFrame.from_dict(auck_data['businesses'])

# %%
#Christchurch Hotel
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {yelp_api_matt}",}
url_params_chr = {"categories" : "hotels, ALL","location" : "Christchurch","limit" : 50}

response_chr = requests.get(url, headers=headers, params=url_params_chr)
chr_data = response_chr.json()
#pprint(chr_data)
df_hotel_chr = pd.DataFrame(chr_data['businesses'])

# %%
df_auckland = df_auckland_shopping.append(df1a, ignore_index=True)
df_auckland = df_Auckland_restaurants.append(df_auckland, ignore_index=True)
df_auckland = df_hotel_auk.append(df_auckland, ignore_index=True)
df_auckland['city'] = 'Auckland'
df_auckland = df_auckland[['city','alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
       'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
       'rating', 'review_count', 'transactions', 'url']]
df_auckland = df_auckland.drop(columns=['alias', 'categories','distance','display_phone','distance','image_url','phone','transactions','url'])
#df_auckland

# %%
df_Wellington = df_wellington_shopping.append(df1w, ignore_index=True)
df_Wellington = df_Wellington_restaurants.append(df_Wellington, ignore_index=True)
df_Wellington = df_hotel_wel.append(df_Wellington, ignore_index=True)
df_Wellington['city'] = 'Wellington'
df_Wellington = df_Wellington[['city','alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
       'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
       'rating', 'review_count', 'transactions', 'url']]
df_Wellington = df_Wellington.drop(columns=['alias', 'categories','distance','display_phone','distance','image_url','phone','transactions','url'])
#df_Wellington

# %%
df_Christchurch = df_christchurch_shopping.append(df1c, ignore_index=True)
df_Christchurch = df_Christchurch_restaurants.append(df_Christchurch, ignore_index=True)
df_Christchurch = df_hotel_chr.append(df_Christchurch, ignore_index=True)
df_Christchurch['city'] = 'Christchurch'
df_Christchurch = df_Christchurch[['city','alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
       'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
       'rating', 'review_count', 'transactions', 'url']]

df_Christchurch = df_Christchurch.drop(columns=['alias', 'categories','distance','display_phone','distance','image_url','phone','transactions','url'])
#df_Christchurch

# %%
df_New_Zealand = df_auckland.append(df_Wellington, ignore_index=True)
df_New_Zealand = df_New_Zealand.append(df_Christchurch, ignore_index=True)
df_New_Zealand
# Out:
#               city                                        coordinates  \
# 0         Auckland    {'latitude': -36.84668, 'longitude': 174.76203}
# 1         Auckland     {'latitude': -37.07745, 'longitude': 174.9422}
# 2         Auckland    {'latitude': -36.81606, 'longitude': 174.76878}
# 3         Auckland  {'latitude': -36.8769493, 'longitude': 174.748...
# 4         Auckland  {'latitude': -36.5926094, 'longitude': 174.698...
# 5         Auckland  {'latitude': -36.8474459016316, 'longitude': 1...
# 6         Auckland  {'latitude': -36.8453689, 'longitude': 174.764...
# 7         Auckland  {'latitude': -36.8454514, 'longitude': 174.742...
# 8         Auckland  {'latitude': -36.9849317, 'longitude': 174.783...
# 9         Auckland  {'latitude': -36.8318901, 'longitude': 174.796...
# 10        Auckland  {'latitude': -36.8883880642874, 'longitude': 1...
# 11        Auckland  {'latitude': -36.8491707, 'longitude': 174.771...
# 12        Auckland  {'latitude': -36.8496094, 'longitude': 174.760...
# 13        Auckland  {'latitude': -36.7909698, 'longitude': 174.770...
# 14        Auckland  {'latitude': -36.8461685, 'longitude': 174.771...
# 15        Auckland  {'latitude': -36.9226303, 'longitude': 174.563...
# 16        Auckland  {'latitude': -36.8479691, 'longitude': 174.765...
# 17        Auckland    {'latitude': -36.85139, 'longitude': 174.76104}
# 18        Auckland  {'latitude': -36.8458221, 'longitude': 174.767...
# 19        Auckland  {'latitude': -36.8534305, 'longitude': 174.763...
# 20        Auckland  {'latitude': -36.972271, 'longitude': 174.7873...
# 21        Auckland  {'latitude': -36.8459862, 'longitude': 174.768...
# 22        Auckland    {'latitude': -36.85382, 'longitude': 174.76823}
# 23        Auckland  {'latitude': -36.9365204, 'longitude': 174.875...
# 24        Auckland  {'latitude': -36.9754157559004, 'longitude': 1...
# 25        Auckland    {'latitude': -36.84642, 'longitude': 174.77462}
# 26        Auckland  {'latitude': -36.8575783, 'longitude': 174.766...
# 27        Auckland   {'latitude': -36.67261, 'longitude': 174.451099}
# 28        Auckland  {'latitude': -36.8814745, 'longitude': 174.775...
# 29        Auckland  {'latitude': -36.8483094199417, 'longitude': 1...
# ...            ...                                                ...
# 2180  Christchurch   {'latitude': -36.88261, 'longitude': 174.733525}
# 2181  Christchurch  {'latitude': -36.9207802, 'longitude': 174.786...
# 2182  Christchurch  {'latitude': -36.8442497, 'longitude': 174.765...
# 2183  Christchurch  {'latitude': -36.848032402546, 'longitude': 17...
# 2184  Christchurch  {'latitude': -36.8577385, 'longitude': 174.760...
# 2185  Christchurch  {'latitude': -36.7288002423115, 'longitude': 1...
# 2186  Christchurch  {'latitude': -36.8486214, 'longitude': 174.766...
# 2187  Christchurch  {'latitude': -36.821118, 'longitude': 174.611678}
# 2188  Christchurch  {'latitude': -36.8826371, 'longitude': 174.635...
# 2189  Christchurch  {'latitude': -36.8691109, 'longitude': 174.76424}
# 2190  Christchurch  {'latitude': -36.849945, 'longitude': 174.7639...
# 2191  Christchurch  {'latitude': -36.9065208, 'longitude': 174.684...
# 2192  Christchurch   {'latitude': -36.8804299, 'longitude': 174.6326}
# 2193  Christchurch  {'latitude': -36.8482552, 'longitude': 174.754...
# 2194  Christchurch  {'latitude': -36.8496473, 'longitude': 174.765...
# 2195  Christchurch  {'latitude': -36.7875749, 'longitude': 174.770...
# 2196  Christchurch  {'latitude': -36.9924919, 'longitude': 174.885...
# 2197  Christchurch    {'latitude': -43.59957, 'longitude': 172.72599}
# 2198  Christchurch    {'latitude': -43.53691, 'longitude': 172.55881}
# 2199  Christchurch    {'latitude': -43.52888, 'longitude': 172.63944}
# 2200  Christchurch    {'latitude': -43.54321, 'longitude': 172.63345}
# 2201  Christchurch   {'latitude': -43.47472, 'longitude': 172.659668}
# 2202  Christchurch  {'latitude': -43.5310096740723, 'longitude': 1...
# 2203  Christchurch  {'latitude': -43.5330009, 'longitude': 172.641...
# 2204  Christchurch  {'latitude': -43.5528183, 'longitude': 172.637...
# 2205  Christchurch  {'latitude': 50.7193336486816, 'longitude': -1...
# 2206  Christchurch  {'latitude': -43.5310096740723, 'longitude': 1...
# 2207  Christchurch  {'latitude': -43.5330009, 'longitude': 172.641...
# 2208  Christchurch  {'latitude': -43.5528183, 'longitude': 172.637...
# 2209  Christchurch  {'latitude': 50.7193336486816, 'longitude': -1...
#
#                           id  is_closed  \
# 0     coJs95Fzy1ALiL3lA6MK5w      False
# 1     bxGjMPTl1fFGbBBqHPOiuQ      False
# 2     Wu2A7NNOGk_wabKePc9W2A      False
# 3     orOalXvpnAZL9XQQdnwIzQ      False
# 4     yv8qXBWoLFQhRs-N8kP8ZQ      False
# 5     SBNPfs2wF3Wep-jfyG9Y2Q      False
# 6     AUqF1GaJMAjJN_88Saw1iA      False
# 7     gPMWCWOapEiIIvmCFp5pFA      False
# 8     2LHb9W62FQ3pc1JyTEFEWA      False
# 9     Qc3K3mTOFKG7k26U-V_e0w      False
# 10    ISfBiwcnWNyDLuuVEgI_cg      False
# 11    _E5IYjNEi__09_FM_N4RBw      False
# 12    5iHETw-7t0aTTTJ5mUfzPg      False
# 13    NIvDdXyNo4JHj2TrfnEdlQ      False
# 14    nzXcRcgTLRYQcrMR5iCpzA      False
# 15    3jSBk5wdrhgAXO7--YgOQg      False
# 16    8HjaLPIAVTMIfrMXHxKUeQ      False
# 17    HoAopesANoMtV0jdg-sjFg      False
# 18    q2EdBfQPxU5UfHAeTSOkDw      False
# 19    PwyT7_QEXwl1zt7Q2XzTmQ      False
# 20    aX1ohnZKe-WLpmoiEyS23w      False
# 21    v17IMU6x7_5MD3iHjzOK7A      False
# 22    gTBx-MfyiWnLgiXMT6sT0g      False
# 23    S5c4PB64cl2YcmAYGss7TA      False
# 24    W-MZEmTu9yN7j7UIMIBIWQ      False
# 25    xC-xxR-bG-t6FpccW-cfAw      False
# 26    M3jGX1PpRfHlDAQPVj7uVw      False
# 27    cZu8uQqzdw1Ak4kwVAMLNA      False
# 28    7l4-1xMh8I6gyOtETrSO5Q      False
# 29    _e-eS3CNVSSUy4qTltn8XQ      False
# ...                      ...        ...
# 2180  ldhf6eqnCakNtrIPPzjiyw      False
# 2181  m-vbahAeKsWfqcRYd9NwLQ      False
# 2182  IDbwVYG873DQGVuk7Ff-GQ      False
# 2183  36A9116uKqmtQWWG417u-A      False
# 2184  CJH50iUT_1u8QHZ1TaVq_w      False
# 2185  PNsLvxDIEdbmFzUBspB7tA      False
# 2186  3R8P3fmZwEAJYbpZe0EJqA      False
# 2187  mn39IEl18E54MuMo1AQSQw      False
# 2188  uxMkgFe16w9_JDfAhj4xTA      False
# 2189  lZeWzLSglYUNlcEOjYNJPw      False
# 2190  yf4CMnf9x163TbgHa32DeA      False
# 2191  KV-JdfWK36t2HxzxCnDlVQ      False
# 2192  6Ri9nb4gL3-DRt7HFEMkew      False
# 2193  qdfMCkaCWe5T420ztECLtg      False
# 2194  QFgEauHbIUiYnoRXk4fqyg      False
# 2195  XuxGoew7HSDiiyKpBxIHEw      False
# 2196  RjVhSCmXxMIx_Kb-TZ4yUw      False
# 2197  tuOIJadvfq0XaSRuNMb_IQ      False
# 2198  8nQhgE5G4pK05Q9hQu-2GQ      False
# 2199  TryYbzCZN78j7Y-LSTVdeQ      False
# 2200  XUuD-DmnEyv-fVuefaArGw      False
# 2201  brI48uPDZVacAh76yELbtw      False
# 2202  mUSKZjrP0Wdi9ZQpy3flwQ      False
# 2203  j4YS5SXn2h7dzzfuCS3Sng      False
# 2204  ylUCwVmXYigKQpq_GtIJOQ      False
# 2205  fuLkh8TOofVAQwVprpifMQ      False
# 2206  mUSKZjrP0Wdi9ZQpy3flwQ      False
# 2207  j4YS5SXn2h7dzzfuCS3Sng      False
# 2208  ylUCwVmXYigKQpq_GtIJOQ      False
# 2209  fuLkh8TOofVAQwVprpifMQ      False
#
#                                                location  \
# 0     {'address1': '35 Hobson St', 'address2': None,...
# 1     {'address1': '407 Great South Rd', 'address2':...
# 2     {'address1': '1 Beresford St', 'address2': '',...
# 3     {'address1': '20 Bellwood Ave', 'address2': 'M...
# 4     {'address1': '246 Hibiscus Coast Highway', 'ad...
# 5     {'address1': '74 Albert St', 'address2': '', '...
# 6     {'address1': '22-26 Albert St', 'address2': 'A...
# 7     {'address1': '57-59 Jervois Rd', 'address2': N...
# 8     {'address1': '18 Airpark Drive', 'address2': '...
# 9     {'address1': '1 Victoria Road, Devonport', 'ad...
# 10    {'address1': '72-112 Greenlane Rd', 'address2'...
# 11    {'address1': '7 Parliament St', 'address2': No...
# 12    {'address1': '119 Hobson St', 'address2': None...
# 13    {'address1': '9-17 Byron Avenue', 'address2': ...
# 14    {'address1': '19 - 23 Anzac Ave', 'address2': ...
# 15    {'address1': '573 Scenic Dr', 'address2': None...
# 16    {'address1': '171 Queen Street', 'address2': '...
# 17    {'address1': '219 Federal Str', 'address2': ''...
# 18    {'address1': '16-20 Fort St', 'address2': None...
# 19    {'address1': '380 Queen St', 'address2': '', '...
# 20    {'address1': '190 Kirkbride Rd', 'address2': N...
# 21    {'address1': '16 Gore St', 'address2': '', 'ad...
# 22    {'address1': '37 Wellesley St', 'address2': ''...
# 23    {'address1': '60 Highbrook Drive', 'address2':...
# 24    {'address1': '12 Tidal Rd', 'address2': 'Mange...
# 25    {'address1': '2 Tapora St', 'address2': '', 'a...
# 26    {'address1': '21 Whitaker Place', 'address2': ...
# 27    {'address1': '1 Railway St', 'address2': '', '...
# 28    {'address1': '189 Manukau Rd', 'address2': 'Ne...
# 29    {'address1': 'Metropolis Building', 'address2'...
# ...                                                 ...
# 2180  {'address1': '80 Saint Lukes Rd', 'address2': ...
# 2181  {'address1': '151 Arthur St', 'address2': 'One...
# 2182  {'address1': '11-19 Customs Street West', 'add...
# 2183  {'address1': 'Chancery Street', 'address2': ''...
# 2184  {'address1': '183 Karangahape Rd', 'address2':...
# 2185  {'address1': '219 Don Mckinnon Dr', 'address2'...
# 2186  {'address1': '55-57 High St', 'address2': None...
# 2187  {'address1': 'Fred Taylor Dr', 'address2': '',...
# 2188  {'address1': '5 Vitasovich Ave', 'address2': '...
# 2189  {'address1': '20 Normanby Road', 'address2': '...
# 2190  {'address1': '21 Elliot Street', 'address2': '...
# 2191  {'address1': '3058 Great North Rd', 'address2'...
# 2192  {'address1': '7 Catherine St', 'address2': Non...
# 2193  {'address1': '210 Victoria St', 'address2': No...
# 2194  {'address1': '230-242 Queen Street', 'address2...
# 2195  {'address1': '52 - 56 Anzac St', 'address2': '...
# 2196  {'address1': 'Great South Rd', 'address2': '',...
# 2197  {'address1': '78a St Davids St', 'address2': '...
# 2198  {'address1': '109 Main South Road', 'address2'...
# 2199  {'address1': '196 Armagh St', 'address2': 'Cen...
# 2200  {'address1': '101 Durham St', 'address2': 'Syd...
# 2201  {'address1': '432 Marshlands Rd', 'address2': ...
# 2202  {'address1': '', 'address2': '', 'address3': '...
# 2203  {'address1': '203 Cashel St', 'address2': None...
# 2204  {'address1': '240 Columbo Street', 'address2':...
# 2205  {'address1': None, 'address2': '', 'address3':...
# 2206  {'address1': '', 'address2': '', 'address3': '...
# 2207  {'address1': '203 Cashel St', 'address2': None...
# 2208  {'address1': '240 Columbo Street', 'address2':...
# 2209  {'address1': None, 'address2': '', 'address3':...
#
#                                           name price  rating  review_count
# 0                               Heritage Hotel    $$     3.5             9
# 1                 Papakura Motor Lodge & Motel     $     5.0             1
# 2                       Auckland Takapuna Oaks   NaN     5.0             1
# 3                  Eden Park Bed and Breakfast   NaN     4.5             2
# 4                            Orewa Beachcomber   $$$     5.0             2
# 5                               Barclay Suites   NaN     4.5             2
# 6                               Stamford Plaza   $$$     3.5            14
# 7                             Abaco On Jervois   NaN     4.5             2
# 8                      Sudima Auckland Airport    $$     2.5             3
# 9                              Esplanade Hotel    $$     2.5             6
# 10                               Novotel Hotel    $$     3.0             1
# 11                Braemar On Parliament Street   NaN     5.0             1
# 12                                Albion Hotel    $$     2.5             3
# 13                  The Spencer On Byron Hotel   $$$     3.5             7
# 14          Celestion Waldorf Apartments Hotel    $$     3.5             4
# 15                 Auckland's Waitakere Estate    $$     4.0             2
# 16                              Citylife Hotel   NaN     4.0             1
# 17                               Ramada Suites    $$     4.0             5
# 18                      Nomads Auckland Hostel   NaN     3.0             8
# 19                                Scenic Hotel    $$     2.5             3
# 20             Traveller's International Hotel   NaN     5.0             1
# 21                       Auckland Harbour Oaks   NaN     4.0             1
# 22                    Econo Lodge City Central   NaN     2.5             2
# 23                             Quest Highbrook    $$     2.0             2
# 24                          Airport Garden Inn   NaN     5.0             1
# 25    Adina Apartment Hotel Auckland Britomart   NaN     4.0             1
# 26                           Empire Apartments   $$$     2.0             1
# 27                             The Grand Hotel    $$     4.0             1
# 28                    Auckland Newmarket Motel   NaN     3.0             1
# 29            Metro Suites Serviced Apartments    $$     4.5             3
# ...                                        ...   ...     ...           ...
# 2180                       Westfield St Luke's    $$     2.5            11
# 2181                               Dress Smart     $     3.5            13
# 2182                  Downtown Shopping Centre    $$     2.0             4
# 2183                           Chancery Square     $     4.0             4
# 2184                         St Kevin's Arcade    $$     4.0             6
# 2185                          Westfield Albany    $$     4.0            11
# 2186                        Little High Street    $$     3.0             7
# 2187                                  Westgate     $     3.5             3
# 2188                     Waitakere Mega Centre   NaN     2.0             1
# 2189                                      BLOC    $$     5.0             4
# 2190                          Atrium on Elliot   $$$     3.0             6
# 2191                                  LynnMall    $$     2.5             9
# 2192                        WestCity Waitakere    $$     2.5             4
# 2193                     Victoria Park Markets   $$$     3.0             7
# 2194                                   Farmers    $$     3.5             3
# 2195                                Shore City   $$$     4.0             1
# 2196                    Westfield Manukau City    $$     3.0             2
# 2197      Parapro - Paragliding & paramotoring   NaN     4.0             1
# 2198                         Kings Swim School   NaN     5.0             1
# 2199                              Crate Escape   NaN     5.0             1
# 2200                                   Dive HQ   NaN     5.0             1
# 2201                             BP Marshlands   NaN     4.0             1
# 2202    Jo Brand Health & Fitness Professional   NaN     5.0             1
# 2203                    Les Mills Christchurch   NaN     1.0             1
# 2204                           Anytime Fitness   NaN     1.0             1
# 2205                          hengistbury head   NaN     4.0             1
# 2206    Jo Brand Health & Fitness Professional   NaN     5.0             1
# 2207                    Les Mills Christchurch   NaN     1.0             1
# 2208                           Anytime Fitness   NaN     1.0             1
# 2209                          hengistbury head   NaN     4.0             1
#
# [2210 rows x 9 columns]

# %%
city_groupby = df_New_Zealand.groupby(['city'])
city_groupby.count()
# Out:
#               coordinates    id  is_closed  location  name  price  rating  \
# city
# Auckland             1373  1373       1373      1373  1373    828    1373
# Christchurch          304   304        304       304   304    111     304
# Wellington            533   533        533       533   533    331     533
#
#               review_count
# city
# Auckland              1373
# Christchurch           304
# Wellington             533

# %%
avg_rating = city_groupby['rating'].mean()
avg_rating
# Out:
# city
# Auckland        3.882010
# Christchurch    3.842105
# Wellington      3.484053
# Name: rating, dtype: float64

# %%
sum_rev_count = city_groupby['review_count'].sum()
sum_rev_count
# Out:
# city
# Auckland         9665
# Christchurch      666
# Wellington      15353
# Name: review_count, dtype: int64

# %%
labels = ['Auckland', 'Christchurch', 'Wellington']
colors = ["orange", "lightcoral", "lightskyblue"]
explode = (0.1, 0, 0)

# %%
plt.pie(avg_rating, explode=explode, labels=labels, colors=colors, 
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("Overall Rating by City")
# Out:
# Text(0.5, 1.0, 'Overall Rating by City')

# %%
x_axis = np.arange(len(sum_rev_count))

# %%
plt.bar(x_axis, sum_rev_count, color='orange', align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Auckland", "Christchurch", "Wellington"])
plt.title("Total Number of Reviews by City")
plt.xlabel("Cities")
plt.ylabel("Number of Reviews")
# Out:
# Text(0, 0.5, 'Number of Reviews')

# %%
NZ = df_New_Zealand["review_count"].sum()

#Acukland
NZ_Auckland = df_New_Zealand.loc[(df_New_Zealand["city"] == 'Auckland')]
NZ_Auckland_group = NZ_Auckland.groupby("rating")
NZ_Auckland_count = NZ_Auckland_group.review_count.count()
NZ_Auckland_sum = NZ_Auckland_group.rating.sum()
NZ_Auckland_avg_rating = (NZ_Auckland_sum/NZ_Auckland_count)
#Wellington
NZ_Wellington = df_New_Zealand.loc[(df_New_Zealand["city"] == 'Wellington')]
NZ_Wellington_group = NZ_Wellington.groupby("rating")
NZ_Wellington_count = NZ_Wellington_group.review_count.count()
NZ_Wellington_sum = NZ_Wellington_group.rating.sum()
NZ_Wellington_avg_rating = (NZ_Wellington_sum/NZ_Wellington_count)
#Christchurch
NZ_Christchurch = df_New_Zealand.loc[(df_New_Zealand["city"] == 'Christchurch')]
NZ_Christchurch_group = NZ_Christchurch.groupby("rating")
NZ_Christchurch_count = NZ_Christchurch_group.review_count.count()
NZ_Christchurch_sum = NZ_Christchurch_group.rating.sum()
NZ_Christchurch_avg_rating = (NZ_Christchurch_sum/NZ_Christchurch_count)

# Build the scatter plots for each city
Auckland_city=plt.scatter(NZ_Auckland_count, NZ_Auckland_avg_rating, marker="x", facecolors="#FF7F50", edgecolors="black",
            alpha=0.7, label='Auckland')

Wellington_city=plt.scatter(NZ_Wellington_count, NZ_Wellington_avg_rating, marker="o", facecolors="#ffd700", edgecolors="black",
           alpha=0.7,  label='Wellington')

Christchurch_city=plt.scatter(NZ_Christchurch_count, NZ_Christchurch_avg_rating, marker="^", facecolors="#87CEEB", edgecolors="black",
          alpha=0.7, label='Christchurch')
# Incorporate the other graph properties
plt.grid(b=None, which='major', axis='both',linewidth=1)
plt.title("New Zealand Ratings")
plt.xlabel("Total Number of Ratings")
plt.ylabel("Rating")
# Create a legend
plt.legend(handles=[Auckland_city, Wellington_city,Christchurch_city], title= "City's", loc="best")
# Incorporate a text label regarding circle size
#textstr = 'Note:\nCircle size correlates with driver count per city\n'
#plt.text(41.2, 33.5, textstr, fontsize=10)

# Save Figure
#plt.savefig("../Images/Ride_Sharing_Data.png")
# Show Figure
plt.show()

# %%
df_hotel_auk['city'] = 'Auckland'
df_hotel_auk = df_hotel_auk[['city','alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
       'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
       'rating', 'review_count', 'transactions', 'url']]
df_hotel_auk = df_hotel_auk.drop(columns=['alias', 'categories','coordinates','distance','display_phone','distance','image_url','id','is_closed','location','phone','transactions','url'])
df_hotel_auk.head()
# Out:
#        city                          name price  rating  review_count
# 0  Auckland                Heritage Hotel    $$     3.5             9
# 1  Auckland  Papakura Motor Lodge & Motel     $     5.0             1
# 2  Auckland        Auckland Takapuna Oaks   NaN     5.0             1
# 3  Auckland   Eden Park Bed and Breakfast   NaN     4.5             2
# 4  Auckland             Orewa Beachcomber   $$$     5.0             2

# %%
hotel_low = df_hotel_auk.loc[(df_hotel_auk['price'] == '$')]
hotel_mid = df_hotel_auk.loc[(df_hotel_auk['price'] == '$$')]
hotel_high = df_hotel_auk.loc[(df_hotel_auk['price'] == '$$$')]

# %%
x_axis_1 = hotel_low['name']
y_axis_1 = hotel_low['rating']

# %%
plt.bar(x_axis_1, y_axis_1, color='lightblue', align="center")
plt.xticks(rotation="vertical")
plt.title("Cheapest Hotel Ratings")
plt.xlabel("Hotels")
plt.ylabel("Ratings")
# Out:
# Text(0, 0.5, 'Ratings')

# %%
x_axis_2 = hotel_mid['name']
y_axis_2 = hotel_mid['rating']

# %%
plt.figure(figsize=(15,5))
plt.bar(x_axis_2, y_axis_2, color='orange', align="center")
plt.xticks(rotation="vertical")
plt.ylim(0, 5.2)
plt.title("Mid Priced Hotel Ratings")
plt.xlabel("Hotels")
plt.ylabel("Ratings")
# Out:
# Text(0, 0.5, 'Ratings')

# %%
x_axis_3 = hotel_high['name']
y_axis_3 = hotel_high['rating']

# %%
plt.bar(x_axis_3, y_axis_3, color='lightcoral', align="center")
plt.xticks(rotation="vertical")
plt.title("High Priced Hotel Ratings")
plt.xlabel("Hotels")
plt.ylabel("Ratings")
# Out:
# Text(0, 0.5, 'Ratings')
