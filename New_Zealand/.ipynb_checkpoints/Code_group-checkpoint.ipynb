# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
from pprint import pprint

# %%
# Yelp API Keys
from nconfig import naveenkey
from sconfig import sindhu_api
from config import yelp_api_matt
from config import yelp_api

# %%
#Auckland Active life pull
def active_life(set_num): 

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {naveenkey}",}
    url_params = {
    "categories" : "active, All",
    "location" : "Auckland",
    "offset" : offset_num,
    "limit" : 50}

    response = requests.get(url, headers = headers, params = url_params)
    return response.json()

for offset_num in np.arange(50,400,50) : 
    try:
        output_json = active_life(offset_num)
        #pprint(offset_num) 
        #pprint(output_json)
        if offset_num == 50:
            df1a = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2a = pd.DataFrame.from_dict(output_json['businesses'])
            df1a = df1a.append(df2a)
    except AttributeError:
        pprint("error at ", offset_num)
# Out:
# C:\Users\blake\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
#Auckland_restaurants
def Auckland_restaurants(set_num):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {yelp_api}",
    }
    url_params = {
        "categories" : "restaurants, All",
        "location" : "Wellington",
        "offset" : offset_num,
        "limit" : 50}
    response = requests.get(url, headers = headers, params = url_params)
    return response.json()


for offset_num in np.arange(50,1000,50) :
    try:
        output_json = Auckland_restaurants(offset_num)
        #pprint(offset_num)
        #pprint(output_json)
        if offset_num == 50:
            df_Auckland_restaurants = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2 = pd.DataFrame.from_dict(output_json['businesses'])
            df_Auckland_restaurants = df_Auckland_restaurants.append(df2)
    except AttributeError:
           print("error at ", offset_num)

# %%
#Auckland Shoppingcenter
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {sindhu_api}",}
url_params_wel = {"term" : "shopping centers","location" : "Auckland"}

response_auck = requests.get(url, headers=headers, params=url_params_wel)
auck_data = response_auck.json()
#pprint(auck_data)
df_auckland_shopping = pd.DataFrame.from_dict(auck_data['businesses'])

# %%
#Auckland hotel pull
def aucklandhotel(set_num): 

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {naveenkey}",}
    url_params = {
    "categories" : "active, All",
    "location" : "Auckland",
    "offset" : offset_num,
    "limit" : 50}

    response = requests.get(url, headers = headers, params = url_params)
    return response.json()

for offset_num in np.arange(50,400,50) : 
    try:
        output_json = aucklandhotel(offset_num)
        #pprint(offset_num) 
        #pprint(output_json)
        if offset_num == 50:
            df_hotel_auk = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2a = pd.DataFrame.from_dict(output_json['businesses'])
            df_hotel_auk = df1a.append(df2a)
    except AttributeError:
        pprint("error at ", offset_num)

# %%
#Wellington Active life pull
def active_life(set_num): 

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {naveenkey}",}
    url_params = {
    "categories" : "active, All",
    "location" : "Wellington",
    "offset" : offset_num,
    "limit" : 50}

    response = requests.get(url, headers = headers, params = url_params)
    return response.json()

for offset_num in np.arange(50,200,50) : 
    try:
        output_json = active_life(offset_num)
        #pprint(offset_num) 
        #pprint(output_json)
        if offset_num == 50:
            df1w = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2w = pd.DataFrame.from_dict(output_json['businesses'])
            df1w = df1w.append(df2w)
    except AttributeError:
        pprint("error at ", offset_num)

# %%
#Wellington restaurants pull
def Wellington_restaurants(set_num):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {yelp_api}",
    }
    url_params = {
        "categories" : "restaurants, All",
        "location" : "Wellington",
        "offset" : offset_num,
        "limit" : 50}
    response = requests.get(url, headers = headers, params = url_params)
    return response.json()


for offset_num in np.arange(50,1000,50) :
    try:
        output_json = Wellington_restaurants(offset_num)
        #pprint(offset_num)
        #pprint(output_json)
        if offset_num == 50:
            df_Wellington_restaurants = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2 = pd.DataFrame.from_dict(output_json['businesses'])
            df_Wellington_restaurants = df_Wellington_restaurants.append(df2)
    except AttributeError:
           print("error at ", offset_num)

# %%
#Wellington Shoppingcenter
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {sindhu_api}",}
url_params_well = {"term" : "shopping centers","location" : "Wellington"}

response_well = requests.get(url, headers=headers, params=url_params_well)
well_data = response_well.json()
#pprint(well_data)
df_wellington_shopping = pd.DataFrame.from_dict(auck_data['businesses'])

# %%
#Wellington Hotel
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {yelp_api_matt}",}
url_params_wel = {"categories" : "hotels, ALL","location" : "Wellington"}

response_wel = requests.get(url, headers=headers, params=url_params_wel)
wel_data = response_wel.json()
#pprint(wel_data)
df_hotel_wel = pd.DataFrame(wel_data['businesses'])

# %%
#Christchurch Active life pull
def active_life(set_num): 

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {naveenkey}",}
    url_params = {
    "categories" : "active, All",
    "location" : "Christchurch",
    "offset" : offset_num,
    "limit" : 50}

    response = requests.get(url, headers = headers, params = url_params)
    return response.json()

for offset_num in np.arange(5,30,5): 
    try:
        output_json = active_life(offset_num)
        #pprint(offset_num) 
        #pprint(output_json)
        if offset_num == 5:
            df1c = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2c = pd.DataFrame.from_dict(output_json['businesses'])
            df1c = df1c.append(df2c)
    except AttributeError:
        pprint("error at ", offset_num)

# %%
#Christchurch_restaurants
def Christchurch_restaurants(set_num):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': f"Bearer {yelp_api}",
    }
    url_params = {
        "categories" : "restaurants, All",
        "location" : "Christchurch",
        "offset" : offset_num,
        "limit" : 50}
    response = requests.get(url, headers = headers, params = url_params)
    return response.json()


for offset_num in np.arange(50,1000,50) :
    try:
        output_json = Christchurch_restaurants(offset_num)
        #pprint(offset_num)
        #pprint(output_json)
        if offset_num == 50:
            df_Christchurch_restaurants = pd.DataFrame.from_dict(output_json['businesses'])
        else:
            df2 = pd.DataFrame.from_dict(output_json['businesses'])
            df_Christchurch_restaurants = df_Christchurch_restaurants.append(df2)
    except AttributeError:
           print("error at ", offset_num)

# %%
#Christchurch Shoppingcenter
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {sindhu_api}",}
url_params_christ = {"term" : "shopping centers","location" : "Christchurch","limit" : 50}

response_christ = requests.get(url, headers=headers, params=url_params_christ)
christ_data = response_christ.json()
#pprint(christ_data)
df_christchurch_shopping = pd.DataFrame.from_dict(auck_data['businesses'])
# Out:
# {'businesses': [{'alias': 're-start-christchurch-2',
#                  'categories': [{'alias': 'shoppingcenters',
#                                  'title': 'Shopping Centers'}],
#                  'coordinates': {'latitude': -43.5331069165978,
#                                  'longitude': 172.635470760371},
#                  'display_phone': '+64 21 841 472',
#                  'distance': 3830.5069984349016,
#                  'id': 'CAeZc4rQfrsvvMxCl9tr7w',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/csuxpakAbNaxXMRIp3oOmA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '114 Cashel St',
#                               'address2': 'Cashel Mall',
#                               'address3': '',
#                               'city': 'Christchurch',
#                               'country': 'NZ',
#                               'display_address': ['114 Cashel St',
#                                                   'Cashel Mall',
#                                                   'Christchurch 8011',
#                                                   'New Zealand'],
#                               'state': 'CAN',
#                               'zip_code': '8011'},
#                  'name': 'Re:START',
#                  'phone': '+6421841472',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 9,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/re-start-christchurch-2?adjust_creative=ZJ6MfwAA15QFUnH4DZ85_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZJ6MfwAA15QFUnH4DZ85_Q'},
#                 {'alias': 'westfield-riccarton-christchurch',
#                  'categories': [{'alias': 'shoppingcenters',
#                                  'title': 'Shopping Centers'}],
#                  'coordinates': {'latitude': -43.53002, 'longitude': 172.59807},
#                  'display_phone': '+64 3-983 4500',
#                  'distance': 2088.4660238102756,
#                  'id': 'EGGP8SFSG8Xf7vr5jnmQTw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z3N7U8cfCE7VI2foDVEjCA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '129 Riccarton Rd',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Christchurch',
#                               'country': 'NZ',
#                               'display_address': ['129 Riccarton Rd',
#                                                   'Christchurch 8041',
#                                                   'New Zealand'],
#                               'state': 'CAN',
#                               'zip_code': '8041'},
#                  'name': 'Westfield Riccarton',
#                  'phone': '+6439834500',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/westfield-riccarton-christchurch?adjust_creative=ZJ6MfwAA15QFUnH4DZ85_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZJ6MfwAA15QFUnH4DZ85_Q'},
#                 {'alias': 'merivale-mall-christchurch',
#                  'categories': [{'alias': 'shoppingcenters',
#                                  'title': 'Shopping Centers'}],
#                  'coordinates': {'latitude': -43.5125313,
#                                  'longitude': 172.6218262},
#                  'display_phone': '+64 3-355 9692',
#                  'distance': 1866.4641626059986,
#                  'id': 'J2Cv3UHxvncbWuGvK_H39A',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '189 Papanui Road',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Christchurch',
#                               'country': 'NZ',
#                               'display_address': ['189 Papanui Road',
#                                                   'Christchurch 8014',
#                                                   'New Zealand'],
#                               'state': 'CAN',
#                               'zip_code': '8014'},
#                  'name': 'Merivale Mall',
#                  'phone': '+6433559692',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/merivale-mall-christchurch?adjust_creative=ZJ6MfwAA15QFUnH4DZ85_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZJ6MfwAA15QFUnH4DZ85_Q'},
#                 {'alias': 'the-hub-hornby-christchurch',
#                  'categories': [{'alias': 'shoppingcenters',
#                                  'title': 'Shopping Centers'}],
#                  'coordinates': {'latitude': -43.5433502,
#                                  'longitude': 172.5231476},
#                  'display_phone': '+64 3-349 7288',
#                  'distance': 6966.1494689211695,
#                  'id': 'p0-Y7lO7Z11JwNff0unkvw',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '418 Main South Rd',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Christchurch',
#                               'country': 'NZ',
#                               'display_address': ['418 Main South Rd',
#                                                   'Christchurch 8042',
#                                                   'New Zealand'],
#                               'state': 'MBH',
#                               'zip_code': '8042'},
#                  'name': 'The Hub Hornby',
#                  'phone': '+6433497288',
#                  'rating': 4.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-hub-hornby-christchurch?adjust_creative=ZJ6MfwAA15QFUnH4DZ85_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZJ6MfwAA15QFUnH4DZ85_Q'},
#                 {'alias': 'the-warehouse-christchurch-3',
#                  'categories': [{'alias': 'deptstores',
#                                  'title': 'Department Stores'}],
#                  'coordinates': {'latitude': -43.5331993,
#                                  'longitude': 172.673996},
#                  'display_phone': '+64 3-389 2004',
#                  'distance': 6570.253558425075,
#                  'id': 'DBSHY11AL1JH4-XI0mUmKw',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '20 Buckleys Rd',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Christchurch',
#                               'country': 'NZ',
#                               'display_address': ['20 Buckleys Rd',
#                                                   'Christchurch 8062',
#                                                   'New Zealand'],
#                               'state': 'OTA',
#                               'zip_code': '8062'},
#                  'name': 'The Warehouse',
#                  'phone': '+6433892004',
#                  'rating': 4.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-warehouse-christchurch-3?adjust_creative=ZJ6MfwAA15QFUnH4DZ85_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZJ6MfwAA15QFUnH4DZ85_Q'},
#                 {'alias': 'fresh-choice-christchurch',
#                  'categories': [{'alias': 'deptstores',
#                                  'title': 'Department Stores'}],
#                  'coordinates': {'latitude': -43.5129862590211,
#                                  'longitude': 172.621183205422},
#                  'display_phone': '+64 3-355 4432',
#                  'distance': 1876.0699320236777,
#                  'id': 'PsYVSgWHq3GSxLEP5Q10bw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2TUZ5Gf_n1IHCcC2AFMk1g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '189 Papanui Rd',
#                               'address2': 'Merivale',
#                               'address3': '',
#                               'city': 'Christchurch',
#                               'country': 'NZ',
#                               'display_address': ['189 Papanui Rd',
#                                                   'Merivale',
#                                                   'Christchurch 8014',
#                                                   'New Zealand'],
#                               'state': 'CAN',
#                               'zip_code': '8014'},
#                  'name': 'Fresh Choice',
#                  'phone': '+6433554432',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/fresh-choice-christchurch?adjust_creative=ZJ6MfwAA15QFUnH4DZ85_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZJ6MfwAA15QFUnH4DZ85_Q'},
#                 {'alias': 'northlands-christchurch-2',
#                  'categories': [{'alias': 'accessories',
#                                  'title': 'Accessories'}],
#                  'coordinates': {'latitude': -43.4060898,
#                                  'longitude': 172.6464233},
#                  'display_phone': '+64 3-352 6535',
#                  'distance': 2387.100299954805,
#                  'id': 'MKzVcFbm2zdc1-Ec0_Eshw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7HRuq1VvwVvYWZkp20EQPw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '55 Main North Rd',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Christchurch',
#                               'country': 'NZ',
#                               'display_address': ['55 Main North Rd',
#                                                   'Christchurch 8052',
#                                                   'New Zealand'],
#                               'state': 'CAN',
#                               'zip_code': '8052'},
#                  'name': 'Northlands',
#                  'phone': '+6433526535',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/northlands-christchurch-2?adjust_creative=ZJ6MfwAA15QFUnH4DZ85_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZJ6MfwAA15QFUnH4DZ85_Q'},
#                 {'alias': 'save-mart-christchurch',
#                  'categories': [{'alias': 'accessories',
#                                  'title': 'Accessories'}],
#                  'coordinates': {'latitude': -43.4901505,
#                                  'longitude': 172.6232147},
#                  'display_phone': '+64 3-354 6296',
#                  'distance': 3028.5391109171483,
#                  'id': 'lb6H4VojkXQUdSt8GtWSOw',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '472 Cranford St',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Christchurch',
#                               'country': 'NZ',
#                               'display_address': ['472 Cranford St',
#                                                   'Christchurch 8051',
#                                                   'New Zealand'],
#                               'state': 'CAN',
#                               'zip_code': '8051'},
#                  'name': 'Save Mart',
#                  'phone': '+6433546296',
#                  'rating': 4.0,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/save-mart-christchurch?adjust_creative=ZJ6MfwAA15QFUnH4DZ85_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZJ6MfwAA15QFUnH4DZ85_Q'}],
#  'region': {'center': {'latitude': -43.51196530709292,
#                        'longitude': 172.59796142578125}},
#  'total': 8}

# %%
#Christchurch Hotel
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': f"Bearer {yelp_api_matt}",}
url_params_chr = {"categories" : "hotels, ALL","location" : "Christchurch","limit" : 50}

response_chr = requests.get(url, headers=headers, params=url_params_chr)
chr_data = response_chr.json()
#pprint(chr_data)
df_hotel_chr = pd.DataFrame(chr_data['businesses'])

# %%
df_auckland = df_auckland_shopping.append(df1a, ignore_index=True)
df_auckland = df_Auckland_restaurants.append(df_auckland, ignore_index=True)
df_auckland = df_hotel_auk.append(df_auckland, ignore_index=True)
df_auckland['city'] = 'Auckland'
df_auckland = df_auckland[['city','alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
       'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
       'rating', 'review_count', 'transactions', 'url']]
df_auckland = df_auckland.drop(columns=['alias', 'categories','distance','display_phone','distance','image_url','phone', 'price','transactions','url'])
#df_auckland

# %%
df_Wellington = df_wellington_shopping.append(df1w, ignore_index=True)
df_Wellington = df_Wellington_restaurants.append(df_Wellington, ignore_index=True)
df_Wellington = df_hotel_wel.append(df_Wellington, ignore_index=True)
df_Wellington['city'] = 'Wellington'
df_Wellington = df_Wellington[['city','alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
       'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
       'rating', 'review_count', 'transactions', 'url']]
df_Wellington = df_Wellington.drop(columns=['alias', 'categories','distance','display_phone','distance','image_url','phone', 'price','transactions','url'])
#df_Wellington

# %%
df_Christchurch = df_christchurch_shopping.append(df1c, ignore_index=True)
df_Christchurch = df_Christchurch_restaurants.append(df_Christchurch, ignore_index=True)
df_Christchurch = df_hotel_chr.append(df_Christchurch, ignore_index=True)
df_Christchurch['city'] = 'Christchurch'
df_Christchurch = df_Christchurch[['city','alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
       'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
       'rating', 'review_count', 'transactions', 'url']]

df_Christchurch = df_Christchurch.drop(columns=['alias', 'categories','distance','display_phone','distance','image_url','phone', 'price','transactions','url'])
#df_Christchurch

# %%
df_New_Zealand = df_auckland.append(df_Wellington, ignore_index=True)
df_New_Zealand = df_New_Zealand.append(df_Christchurch, ignore_index=True)
df_New_Zealand
# Out:
#               city                                        coordinates  \
# 0         Auckland  {'latitude': -36.8465822, 'longitude': 174.761...
# 1         Auckland  {'latitude': -36.7857895, 'longitude': 174.768...
# 2         Auckland  {'latitude': -36.9027609, 'longitude': 174.845...
# 3         Auckland  {'latitude': -36.8190969, 'longitude': 174.795...
# 4         Auckland  {'latitude': -36.8550911, 'longitude': 174.738...
# 5         Auckland  {'latitude': -36.844935, 'longitude': 174.7391...
# 6         Auckland  {'latitude': -36.8481244, 'longitude': 174.762...
# 7         Auckland    {'latitude': -36.84786, 'longitude': 174.83017}
# 8         Auckland  {'latitude': -36.8790786, 'longitude': 174.725...
# 9         Auckland  {'latitude': -36.7650031969009, 'longitude': 1...
# 10        Auckland  {'latitude': -36.8797447297314, 'longitude': 1...
# 11        Auckland  {'latitude': -36.8865460657551, 'longitude': 1...
# 12        Auckland  {'latitude': -36.8489217, 'longitude': 174.786...
# 13        Auckland  {'latitude': -36.8519065, 'longitude': 174.779...
# 14        Auckland  {'latitude': -36.8615380904248, 'longitude': 1...
# 15        Auckland  {'latitude': -36.7598911891261, 'longitude': 1...
# 16        Auckland  {'latitude': -36.8454243, 'longitude': 174.758...
# 17        Auckland  {'latitude': -36.8818588, 'longitude': 174.726...
# 18        Auckland  {'latitude': -36.8616648, 'longitude': 174.762...
# 19        Auckland  {'latitude': -36.870242, 'longitude': 174.7449...
# 20        Auckland  {'latitude': -36.8670196152585, 'longitude': 1...
# 21        Auckland  {'latitude': -36.8877907, 'longitude': 174.747...
# 22        Auckland  {'latitude': -36.8822873, 'longitude': 174.761...
# 23        Auckland  {'latitude': -36.8505898, 'longitude': 174.761...
# 24        Auckland  {'latitude': -36.8676127, 'longitude': 174.777...
# 25        Auckland  {'latitude': -36.8429032, 'longitude': 174.730...
# 26        Auckland  {'latitude': -36.8504483618643, 'longitude': 1...
# 27        Auckland  {'latitude': -36.7670000473126, 'longitude': 1...
# 28        Auckland  {'latitude': -36.8828201, 'longitude': 174.814...
# 29        Auckland  {'latitude': -36.863639831543, 'longitude': 17...
# ...            ...                                                ...
# 1857  Christchurch   {'latitude': -36.88261, 'longitude': 174.733525}
# 1858  Christchurch  {'latitude': -36.9207802, 'longitude': 174.786...
# 1859  Christchurch  {'latitude': -36.8442497, 'longitude': 174.765...
# 1860  Christchurch  {'latitude': -36.848032402546, 'longitude': 17...
# 1861  Christchurch  {'latitude': -36.8577385, 'longitude': 174.760...
# 1862  Christchurch  {'latitude': -36.7288002423115, 'longitude': 1...
# 1863  Christchurch  {'latitude': -36.8486214, 'longitude': 174.766...
# 1864  Christchurch  {'latitude': -36.821118, 'longitude': 174.611678}
# 1865  Christchurch  {'latitude': -36.8826371, 'longitude': 174.635...
# 1866  Christchurch  {'latitude': -36.8691109, 'longitude': 174.76424}
# 1867  Christchurch  {'latitude': -36.849945, 'longitude': 174.7639...
# 1868  Christchurch  {'latitude': -36.9065208, 'longitude': 174.684...
# 1869  Christchurch   {'latitude': -36.8804299, 'longitude': 174.6326}
# 1870  Christchurch  {'latitude': -36.8482552, 'longitude': 174.754...
# 1871  Christchurch  {'latitude': -36.8496473, 'longitude': 174.765...
# 1872  Christchurch  {'latitude': -36.7875749, 'longitude': 174.770...
# 1873  Christchurch  {'latitude': -36.9924919, 'longitude': 174.885...
# 1874  Christchurch    {'latitude': -43.59957, 'longitude': 172.72599}
# 1875  Christchurch    {'latitude': -43.53691, 'longitude': 172.55881}
# 1876  Christchurch    {'latitude': -43.52888, 'longitude': 172.63944}
# 1877  Christchurch    {'latitude': -43.54321, 'longitude': 172.63345}
# 1878  Christchurch   {'latitude': -43.47472, 'longitude': 172.659668}
# 1879  Christchurch  {'latitude': -43.5310096740723, 'longitude': 1...
# 1880  Christchurch  {'latitude': -43.5330009, 'longitude': 172.641...
# 1881  Christchurch  {'latitude': -43.5528183, 'longitude': 172.637...
# 1882  Christchurch  {'latitude': 50.7193336486816, 'longitude': -1...
# 1883  Christchurch  {'latitude': -43.5310096740723, 'longitude': 1...
# 1884  Christchurch  {'latitude': -43.5330009, 'longitude': 172.641...
# 1885  Christchurch  {'latitude': -43.5528183, 'longitude': 172.637...
# 1886  Christchurch  {'latitude': 50.7193336486816, 'longitude': -1...
#
#                           id  is_closed  \
# 0     vbNHWGYOh0MzdAYUVfLl1Q      False
# 1     UO1pmZaFjgT2ku-4vUbOCQ      False
# 2     WQidcq_i4SL7abXpeyVFPg      False
# 3     VyFFYUMy1xSWc6-X_pAhpQ      False
# 4     P0IcxETrnLJYxG0j1uVeyg      False
# 5     ZyqDE9qG3-1uDp1kenn20g      False
# 6     0zfbUMKt44xJPuhIMDRePw      False
# 7     P7C1Tj5-CjJ9lpDYbcDQTQ      False
# 8     aBOuzX-ORClyBXHA2DAA9g      False
# 9     iw34CqAciYkSHSVN5AkQEw      False
# 10    KxDzyasHuVpEUCC4kDBx1A      False
# 11    xW8zgbybVPY9FnUIz0zZ0g      False
# 12    YQhv1qa9T483XH1843yp-w      False
# 13    Esx7FcNtliZftzUeCzI2Vw      False
# 14    6M_bg92CSfe47byEbOoHLA      False
# 15    VsxH31yd9RcTqa2VQJVRlA      False
# 16    3L5O6R2onZuOqTZF69yC3w      False
# 17    qToUpartamloazWh5-3PaQ      False
# 18    Cs8sd7vsJy46YxcRSiBs0A      False
# 19    BBYKjDgDXR_rD_qAo5_Spg      False
# 20    YuY4WbXCkbNWSxuWs5eCnQ      False
# 21    v5o8HLucVfO_26Dvx3KXwg      False
# 22    k06TmnJgPBhWkF6d4w-PWQ      False
# 23    9jiTceSbfVOvGZbfGF57jA      False
# 24    IKrEYTxFp9IT0qVhjxofUQ      False
# 25    lVdRsMKDiblm4KsTiKzrxA      False
# 26    LqVWyoJRtsBQ6jYfHTO3VQ      False
# 27    GtRRhJZKuxrgNJvpP60UyA      False
# 28    oOhOor9UfFjb2PzN3afm_Q      False
# 29    3POX5WAu83wC3jB4LlRE4Q      False
# ...                      ...        ...
# 1857  ldhf6eqnCakNtrIPPzjiyw      False
# 1858  m-vbahAeKsWfqcRYd9NwLQ      False
# 1859  IDbwVYG873DQGVuk7Ff-GQ      False
# 1860  36A9116uKqmtQWWG417u-A      False
# 1861  CJH50iUT_1u8QHZ1TaVq_w      False
# 1862  PNsLvxDIEdbmFzUBspB7tA      False
# 1863  3R8P3fmZwEAJYbpZe0EJqA      False
# 1864  mn39IEl18E54MuMo1AQSQw      False
# 1865  uxMkgFe16w9_JDfAhj4xTA      False
# 1866  lZeWzLSglYUNlcEOjYNJPw      False
# 1867  yf4CMnf9x163TbgHa32DeA      False
# 1868  KV-JdfWK36t2HxzxCnDlVQ      False
# 1869  6Ri9nb4gL3-DRt7HFEMkew      False
# 1870  qdfMCkaCWe5T420ztECLtg      False
# 1871  QFgEauHbIUiYnoRXk4fqyg      False
# 1872  XuxGoew7HSDiiyKpBxIHEw      False
# 1873  RjVhSCmXxMIx_Kb-TZ4yUw      False
# 1874  tuOIJadvfq0XaSRuNMb_IQ      False
# 1875  8nQhgE5G4pK05Q9hQu-2GQ      False
# 1876  TryYbzCZN78j7Y-LSTVdeQ      False
# 1877  XUuD-DmnEyv-fVuefaArGw      False
# 1878  brI48uPDZVacAh76yELbtw      False
# 1879  mUSKZjrP0Wdi9ZQpy3flwQ      False
# 1880  j4YS5SXn2h7dzzfuCS3Sng      False
# 1881  ylUCwVmXYigKQpq_GtIJOQ      False
# 1882  fuLkh8TOofVAQwVprpifMQ      False
# 1883  mUSKZjrP0Wdi9ZQpy3flwQ      False
# 1884  j4YS5SXn2h7dzzfuCS3Sng      False
# 1885  ylUCwVmXYigKQpq_GtIJOQ      False
# 1886  fuLkh8TOofVAQwVprpifMQ      False
#
#                                                location  \
# 0     {'address1': 'Unit D', 'address2': '80 Wyndham...
# 1     {'address1': 'Killarney Street', 'address2': '...
# 2     {'address1': '100 Ireland Road', 'address2': '...
# 3     {'address1': 'Lake Road, Devonport', 'address2...
# 4     {'address1': '166 Richmond Road', 'address2': ...
# 5     {'address1': '105A Jervois Rd', 'address2': No...
# 6     {'address1': 'Sky Tower', 'address2': 'Federal...
# 7     {'address1': 'Mission Bay', 'address2': '', 'a...
# 8     {'address1': '773 New North Rd', 'address2': '...
# 9     {'address1': 'Craig Road, Milford', 'address2'...
# 10    {'address1': '773 New North Rd', 'address2': '...
# 11    {'address1': 'Corner Balmoral Rd & Dominion Rd...
# 12    {'address1': '85-87 Gladstone Road', 'address2...
# 13    {'address1': '21 Bath Street', 'address2': 'Pa...
# 14    {'address1': 'Maunsell Road', 'address2': '', ...
# 15    {'address1': '3 The Esplanade', 'address2': 'C...
# 16    {'address1': 'Viaduct Harbour', 'address2': ''...
# 17    {'address1': '31 Alberton Ave', 'address2': No...
# 18    {'address1': '4 Glenside Cres', 'address2': 'E...
# 19    {'address1': '11 Central Avenue', 'address2': ...
# 20    {'address1': '8 Shaddock St', 'address2': 'Ede...
# 21    {'address1': '610 Dominion Rd', 'address2': No...
# 22    {'address1': '3 Ngauruhoe St', 'address2': 'or...
# 23    {'address1': '190 Federal St', 'address2': Non...
# 24    {'address1': '489 Khyber Pass Rd', 'address2':...
# 25    {'address1': 'Cremorne Street', 'address2': 'H...
# 26    {'address1': 'Tamaki Drive', 'address2': 'Kohi...
# 27    {'address1': 'Milford', 'address2': '', 'addre...
# 28    {'address1': '33 Haast St', 'address2': None, ...
# 29    {'address1': 'auckland zoo', 'address2': '', '...
# ...                                                 ...
# 1857  {'address1': '80 Saint Lukes Rd', 'address2': ...
# 1858  {'address1': '151 Arthur St', 'address2': 'One...
# 1859  {'address1': '11-19 Customs Street West', 'add...
# 1860  {'address1': 'Chancery Street', 'address2': ''...
# 1861  {'address1': '183 Karangahape Rd', 'address2':...
# 1862  {'address1': '219 Don Mckinnon Dr', 'address2'...
# 1863  {'address1': '55-57 High St', 'address2': None...
# 1864  {'address1': 'Fred Taylor Dr', 'address2': '',...
# 1865  {'address1': '5 Vitasovich Ave', 'address2': '...
# 1866  {'address1': '20 Normanby Road', 'address2': '...
# 1867  {'address1': '21 Elliot Street', 'address2': '...
# 1868  {'address1': '3058 Great North Rd', 'address2'...
# 1869  {'address1': '7 Catherine St', 'address2': Non...
# 1870  {'address1': '210 Victoria St', 'address2': No...
# 1871  {'address1': '230-242 Queen Street', 'address2...
# 1872  {'address1': '52 - 56 Anzac St', 'address2': '...
# 1873  {'address1': 'Great South Rd', 'address2': '',...
# 1874  {'address1': '78a St Davids St', 'address2': '...
# 1875  {'address1': '109 Main South Road', 'address2'...
# 1876  {'address1': '196 Armagh St', 'address2': 'Cen...
# 1877  {'address1': '101 Durham St', 'address2': 'Syd...
# 1878  {'address1': '432 Marshlands Rd', 'address2': ...
# 1879  {'address1': '', 'address2': '', 'address3': '...
# 1880  {'address1': '203 Cashel St', 'address2': None...
# 1881  {'address1': '240 Columbo Street', 'address2':...
# 1882  {'address1': None, 'address2': '', 'address3':...
# 1883  {'address1': '', 'address2': '', 'address3': '...
# 1884  {'address1': '203 Cashel St', 'address2': None...
# 1885  {'address1': '240 Columbo Street', 'address2':...
# 1886  {'address1': None, 'address2': '', 'address3':...
#
#                                         name  rating  review_count
# 0                          Adventure Capital     4.0             5
# 1             North Shore Leisure - Takapuna     4.0             5
# 2                              Panmure Basin     4.0             5
# 3                        Devonport Skatepark     5.0             3
# 4                                Barrefigure     5.0             4
# 5                      Ponsonby Bowling Club     4.5             4
# 6                                   Sky Jump     4.0             5
# 7                    Mission Bay Watersports     4.5             3
# 8                             YMCA Mt Albert     3.5             6
# 9                               Milford Park     4.0             5
# 10                               Rocket Park     3.5             6
# 11                              Potters Park     4.0             5
# 12                   Dove-Myer Robinson Park     4.0             4
# 13                                 Yoga Tech     4.5             3
# 14                  Parnell Lawn Tennis Club     5.0             2
# 15                  Castor Bay Beach Reserve     4.0             5
# 16       Auckland's Whale and Dolphin Safari     4.0             4
# 17                                 Mt Albert     4.0             5
# 18                              Ludus Magnus     5.0             2
# 19                                Nixon Park     3.5             5
# 20                           AndFit Crossfit     5.0             2
# 21                              Clip N'Climb     4.0             4
# 22                             Essex Reserve     4.0             4
# 23                              Yoga Academy     4.5             3
# 24                           The Yoga Corner     5.0             2
# 25                          Cremorne Reserve     5.0             2
# 26                          Kohimarama Beach     4.0             4
# 27                             Milford Beach     4.0             4
# 28        College Rifles Rugby Football Club     4.0             4
# 29                                  Auckland     5.0             2
# ...                                      ...     ...           ...
# 1857                     Westfield St Luke's     2.5            11
# 1858                             Dress Smart     3.5            13
# 1859                Downtown Shopping Centre     2.0             4
# 1860                         Chancery Square     4.0             4
# 1861                       St Kevin's Arcade     4.0             6
# 1862                        Westfield Albany     4.0            11
# 1863                      Little High Street     3.0             7
# 1864                                Westgate     3.5             3
# 1865                   Waitakere Mega Centre     2.0             1
# 1866                                    BLOC     5.0             4
# 1867                        Atrium on Elliot     3.0             6
# 1868                                LynnMall     2.5             9
# 1869                      WestCity Waitakere     2.5             4
# 1870                   Victoria Park Markets     3.0             7
# 1871                                 Farmers     3.5             3
# 1872                              Shore City     4.0             1
# 1873                  Westfield Manukau City     3.0             2
# 1874    Parapro - Paragliding & paramotoring     4.0             1
# 1875                       Kings Swim School     5.0             1
# 1876                            Crate Escape     5.0             1
# 1877                                 Dive HQ     5.0             1
# 1878                           BP Marshlands     4.0             1
# 1879  Jo Brand Health & Fitness Professional     5.0             1
# 1880                  Les Mills Christchurch     1.0             1
# 1881                         Anytime Fitness     1.0             1
# 1882                        hengistbury head     4.0             1
# 1883  Jo Brand Health & Fitness Professional     5.0             1
# 1884                  Les Mills Christchurch     1.0             1
# 1885                         Anytime Fitness     1.0             1
# 1886                        hengistbury head     4.0             1
#
# [1887 rows x 8 columns]

# %%
NZ = df_New_Zealand["review_count"].sum()

#Acukland
NZ_Auckland = df_New_Zealand.loc[(df_New_Zealand["city"] == 'Auckland')]
NZ_Auckland_group = NZ_Auckland.groupby("rating")
NZ_Auckland_count = NZ_Auckland_group.review_count.count()
NZ_Auckland_sum = NZ_Auckland_group.rating.sum()
NZ_Auckland_avg_rating = (NZ_Auckland_sum/NZ_Auckland_count)
#Wellington
NZ_Wellington = df_New_Zealand.loc[(df_New_Zealand["city"] == 'Wellington')]
NZ_Wellington_group = NZ_Wellington.groupby("rating")
NZ_Wellington_count = NZ_Wellington_group.review_count.count()
NZ_Wellington_sum = NZ_Wellington_group.rating.sum()
NZ_Wellington_avg_rating = (NZ_Wellington_sum/NZ_Wellington_count)
#Christchurch
NZ_Christchurch = df_New_Zealand.loc[(df_New_Zealand["city"] == 'Christchurch')]
NZ_Christchurch_group = NZ_Christchurch.groupby("rating")
NZ_Christchurch_count = NZ_Christchurch_group.review_count.count()
NZ_Christchurch_sum = NZ_Christchurch_group.rating.sum()
NZ_Christchurch_avg_rating = (NZ_Christchurch_sum/NZ_Christchurch_count)

# Build the scatter plots for each city
Acukland_city=plt.scatter(NZ_Acukland_count, NZ_Acukland_avg_rating, marker="x", facecolors="#FF7F50", edgecolors="black",
             alpha=0.7, label='Auckland')

Wellington_city=plt.scatter(NZ_Wellington_count, NZ_Wellington_avg_rating, marker="o", facecolors="#ffd700", edgecolors="black",
            alpha=0.7,  label='Wellington')

Christchurch_city=plt.scatter(NZ_Christchurch_count, NZ_Christchurch_avg_rating, marker="^", facecolors="#87CEEB", edgecolors="black",
           alpha=0.7, label='Christchurch')
# Incorporate the other graph properties
plt.grid(b=None, which='major', axis='both',linewidth=1)
plt.title("New Zealand Ratings")
plt.xlabel("Total Number of Ratings")
plt.ylabel("Rating")
# Create a legend
plt.legend(handles=[Acukland_city, Wellington_city,Christchurch_city], title= "City's", loc="best")
# Incorporate a text label regarding circle size
#textstr = 'Note:\nCircle size correlates with driver count per city\n'
#plt.text(41.2, 33.5, textstr, fontsize=10)

# Save Figure
#plt.savefig("../Images/Ride_Sharing_Data.png")
# Show Figure
plt.show()

# %%
df_hotel_chr
# Out:
#                                                 alias  \
# 0                             the-george-christchurch
# 1          rendezvous-hotel-christchurch-christchurch
# 2        crowne-plaza-hotel-christchurch-christchurch
# 3            rydges-latimer-christchurch-christchurch
# 4              copthorne-hotel-commodore-christchurch
# 5                  heritage-christchurch-christchurch
# 6            airport-gateway-motor-lodge-christchurch
# 7   chateau-on-the-park-christchurch-a-doubletree-...
# 8                 centrepoint-on-colombo-christchurch
# 9                   novotel-christchurch-christchurch
# 10                christchurch-cathedral-christchurch
# 11            quality-towers-on-the-park-christchurch
# 12                        merivale-manor-christchurch
# 13           elizas-manor-boutique-hotel-christchurch
# 14                306-on-riccarton-motel-christchurch
# 15                     belmont-motor-inn-christchurch
# 16                    quality-hotel-elms-christchurch
# 17              166-majestic-court-motel-christchurch
# 18               roma-on-riccarton-motel-christchurch
# 19                      the-george-hotel-christchurch
# 20            airport-christchurch-motel-christchurch
# 21                      home-lea-b-and-b-christchurch
# 22               avonhead-garden-motel-christchurch-2
# 23          canterbury-house-backpackers-christchurch
# 24                           aotea-motel-christchurch
# 25                   breakfree-on-cashel-christchurch
# 26          pavilions-hotel-christchurch-christchurch
# 27                             hotel-115-christchurch
# 28                 pacific-view-paradise-christchurch
# 29                      designer-cottage-christchurch
# 30                      rendezvous-hotel-christchurch
# 31             arthurs-court-motor-lodge-christchurch
# 32                    parkview-on-hagley-christchurch
# 33              heartland-hotel-cotswold-christchurch
# 34     westside-motor-lodge-christchurch-christchurch
# 35                   camelot-motor-lodge-christchurch
# 36                   colombo-in-the-city-christchurch
# 37                          boatshed-bar-christchurch
# 38                         airways-motel-christchurch
# 39         city-central-motel-apartments-christchurch
# 40     sudima-hotel-christchurch-airport-christchurch
# 41            addington-court-motel-christchurch-city
# 42               ibis-christchurch-hotel-christchurch
# 43                         admiral-motel-christchurch
# 44        bella-vista-motel-christchurch-christchurch
# 45          comfort-hotel-carlton-mill-christchurch-2
# 46        econo-lodge-canterbury-court-christchurch-2
# 47                 comfort-inn-riccarton-christchurch
# 48         quest-apartments-christchurch-christchurch
#
#                                            categories  \
# 0            [{'alias': 'hotels', 'title': 'Hotels'}]
# 1            [{'alias': 'hotels', 'title': 'Hotels'}]
# 2            [{'alias': 'hotels', 'title': 'Hotels'}]
# 3            [{'alias': 'hotels', 'title': 'Hotels'}]
# 4            [{'alias': 'hotels', 'title': 'Hotels'}]
# 5            [{'alias': 'hotels', 'title': 'Hotels'}]
# 6            [{'alias': 'hotels', 'title': 'Hotels'}]
# 7            [{'alias': 'hotels', 'title': 'Hotels'}]
# 8            [{'alias': 'hotels', 'title': 'Hotels'}]
# 9            [{'alias': 'hotels', 'title': 'Hotels'}]
# 10  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...
# 11           [{'alias': 'hotels', 'title': 'Hotels'}]
# 12           [{'alias': 'hotels', 'title': 'Hotels'}]
# 13           [{'alias': 'hotels', 'title': 'Hotels'}]
# 14           [{'alias': 'hotels', 'title': 'Hotels'}]
# 15           [{'alias': 'hotels', 'title': 'Hotels'}]
# 16           [{'alias': 'hotels', 'title': 'Hotels'}]
# 17           [{'alias': 'hotels', 'title': 'Hotels'}]
# 18           [{'alias': 'hotels', 'title': 'Hotels'}]
# 19           [{'alias': 'hotels', 'title': 'Hotels'}]
# 20           [{'alias': 'hotels', 'title': 'Hotels'}]
# 21           [{'alias': 'hotels', 'title': 'Hotels'}]
# 22           [{'alias': 'hotels', 'title': 'Hotels'}]
# 23           [{'alias': 'hotels', 'title': 'Hotels'}]
# 24           [{'alias': 'hotels', 'title': 'Hotels'}]
# 25           [{'alias': 'hotels', 'title': 'Hotels'}]
# 26           [{'alias': 'hotels', 'title': 'Hotels'}]
# 27           [{'alias': 'hotels', 'title': 'Hotels'}]
# 28           [{'alias': 'hotels', 'title': 'Hotels'}]
# 29           [{'alias': 'hotels', 'title': 'Hotels'}]
# 30           [{'alias': 'hotels', 'title': 'Hotels'}]
# 31           [{'alias': 'hotels', 'title': 'Hotels'}]
# 32           [{'alias': 'hotels', 'title': 'Hotels'}]
# 33           [{'alias': 'hotels', 'title': 'Hotels'}]
# 34           [{'alias': 'hotels', 'title': 'Hotels'}]
# 35           [{'alias': 'hotels', 'title': 'Hotels'}]
# 36           [{'alias': 'hotels', 'title': 'Hotels'}]
# 37           [{'alias': 'hotels', 'title': 'Hotels'}]
# 38           [{'alias': 'hotels', 'title': 'Hotels'}]
# 39           [{'alias': 'hotels', 'title': 'Hotels'}]
# 40           [{'alias': 'hotels', 'title': 'Hotels'}]
# 41           [{'alias': 'hotels', 'title': 'Hotels'}]
# 42           [{'alias': 'hotels', 'title': 'Hotels'}]
# 43           [{'alias': 'hotels', 'title': 'Hotels'}]
# 44           [{'alias': 'hotels', 'title': 'Hotels'}]
# 45           [{'alias': 'hotels', 'title': 'Hotels'}]
# 46           [{'alias': 'hotels', 'title': 'Hotels'}]
# 47           [{'alias': 'hotels', 'title': 'Hotels'}]
# 48           [{'alias': 'hotels', 'title': 'Hotels'}]
#
#                                           coordinates    display_phone  \
# 0   {'latitude': -43.5257988, 'longitude': 172.628...   +64 3-379 4560
# 1   {'latitude': -43.5301565, 'longitude': 172.639...   +64 3-943 3888
# 2     {'latitude': -43.52906, 'longitude': 172.63681}   +64 6437412800
# 3   {'latitude': -43.5305214, 'longitude': 172.643...   +64 3-379 6760
# 4   {'latitude': -43.4974213, 'longitude': 172.556...   +64 3-358 8129
# 5   {'latitude': -43.5311508, 'longitude': 172.638...   +64 3-983 4800
# 6   {'latitude': -43.4992294, 'longitude': 172.560...   +64 3-358 7093
# 7     {'latitude': -43.52638, 'longitude': 172.61229}   +64 3-348 8999
# 8   {'latitude': -43.5237007, 'longitude': 172.636...   +64 3-377 0859
# 9     {'latitude': -43.53032, 'longitude': 172.63745}    +64 643722111
# 10  {'latitude': -43.530938299831, 'longitude': 17...   +64 3-363 4420
# 11  {'latitude': -43.5268211, 'longitude': 172.611...   +64 3-344 1977
# 12  {'latitude': -43.5150951446913, 'longitude': 1...   +64 3-355 7731
# 13  {'latitude': -43.52108, 'longitude': 172.6327362}   +64 3-366 8584
# 14    {'latitude': -43.53123, 'longitude': 172.57899}   +64 6433434306
# 15  {'latitude': -43.5211436, 'longitude': 172.638...   +64 3-379 4037
# 16  {'latitude': -43.4987799, 'longitude': 172.609...   +64 6433553577
# 17  {'latitude': -43.5299414, 'longitude': 172.594...   +64 3-982 8162
# 18  {'latitude': -43.5290184, 'longitude': 172.607...   +64 3-341 1189
# 19  {'latitude': -43.5257988, 'longitude': 172.628...   +64 3-379 4560
# 20  {'latitude': -43.498661, 'longitude': 172.5614...   +64 3-977 4970
# 21  {'latitude': -43.520649, 'longitude': 172.6391...   +64 3-379 9977
# 22    {'latitude': -43.52708, 'longitude': 172.55678}  +64 800 805 010
# 23  {'latitude': -43.5199618106431, 'longitude': 1...   +64 3-377 8108
# 24  {'latitude': -43.5210419, 'longitude': 172.647...   +64 3-377 7188
# 25  {'latitude': -43.5330523593638, 'longitude': 1...  +64 800 448 891
# 26  {'latitude': -43.5189896, 'longitude': 172.626...   +64 3-355 5633
# 27  {'latitude': -43.5306706730023, 'longitude': 1...
# 28  {'latitude': -43.5814095, 'longitude': 172.642...   +64 3-332 6992
# 29  {'latitude': -43.5485497, 'longitude': 172.640...   +64 3-377 8088
# 30  {'latitude': -43.5299835, 'longitude': 172.639...   +64 3-943 3888
# 31  {'latitude': -43.5153503, 'longitude': 172.638...   +64 3-366 9085
# 32  {'latitude': -43.5289612, 'longitude': 172.611...
# 33  {'latitude': -43.5165099, 'longitude': 172.625...   +64 3-355 3535
# 34  {'latitude': -43.5310707, 'longitude': 172.581...   +64 3-341 7254
# 35  {'latitude': -43.5195465, 'longitude': 172.627...   +64 3-355 9124
# 36  {'latitude': -43.5235481, 'longitude': 172.636...   +64 3-365 5378
# 37  {'latitude': -43.5329895, 'longitude': 172.635...   +64 3-365 0859
# 38  {'latitude': -43.5192934108799, 'longitude': 1...   +64 3-342 9464
# 39  {'latitude': -43.5324211, 'longitude': 172.645...   +64 3-379 0540
# 40  {'latitude': -43.4899406, 'longitude': 172.545...
# 41  {'latitude': -43.5465698, 'longitude': 172.606...   +64 3-339 4211
# 42  {'latitude': -43.5319099, 'longitude': 172.635...   +64 3-367 8666
# 43   {'latitude': -43.52108, 'longitude': 172.638382}   +64 3-379 3554
# 44  {'latitude': -43.520649, 'longitude': 172.6389...   +64 3-377 3363
# 45  {'latitude': -43.5206413, 'longitude': 172.626...
# 46  {'latitude': -43.54932, 'longitude': 172.6031099}   +64 6433388351
# 47     {'latitude': -43.53094, 'longitude': 172.5827}   +64 6433411280
# 48  {'latitude': -43.5308113, 'longitude': 172.638...
#
#        distance                      id  \
# 0   2898.913416  fF9KY9lyviCKkFzHMj0yRA
# 1   3882.011397  qCHWHxq4cgmR3rNMzhVHUg
# 2   3677.316923  b8SgoErfbP_IBIIx96n4jA
# 3   4220.702251  RR0Qa0zMvVegry5ob3hB9g
# 4   3730.633064  w0Jul7UjWLLHx1LcHQOcfg
# 5   3871.924009  Nd8LH-Y3W2jZQ6KVyZ8lNQ
# 6   3377.189741  fCQm7SFS7FxIhW5EEmHI0g
# 7   1950.704289  _Y142s9eSeAHELT97nExdg
# 8   3351.035717  dKKq2rohqvfNlErP14763w
# 9   3786.393599  z2w7w0KN6GwHbkQFt2sRSg
# 10  3803.674809  0gmjaOIvvojSsO99EFB2vg
# 11  2007.953794  G0umICs4h0vrmTfBG25meg
# 12  2144.706672  6ExexW7fE8n6yIx1JVtzqw
# 13  2990.111831  dBGf2qNujsrMoC1ZD9ploQ
# 14  2634.440528  20iHdhRk1jvBvfKOVbgctw
# 15  3434.357163  oXFhFUtEQ5AbbMoIlziCcw
# 16  1774.998365  F0scdxmkR5EbxBarsej8sg
# 17  2021.639829  QJox2ldFL_FvqEbT22p6gA
# 18  2028.258357  D4JZJZCROi6c1Uo6idqsIA
# 19  2898.913416  R55KV7WdZMni4VZYDNmNng
# 20  3310.179045  1ctDqUeukNNUKUd8gsM9Gg
# 21  3458.387507  PRWakJt3nH31d3_chhHBdQ
# 22  3725.777560  4Vb9TfVRByBMug9F8OI4_A
# 23  3797.982968  4U2_nn7L2khu3hR_ALWmvg
# 24  4136.687068  SdD9A8a5YPQ712fi6prwXQ
# 25  4048.534627  sujfV8jJt_fHyT_RhwW4LQ
# 26  2478.107043  IQl7bA1D6e8C04AZ1jv6KQ
# 27  3895.146526  LDvFvt8TZHk3mA9qsWDfyA
# 28  8497.500970  5PKMIALxhPRngpIXeV3Yow
# 29  5328.268232  -FdbO_BNKVq5XPeDDzHNAA
# 30  3869.357644  b9UoYrZdI35QpfmLyldmcg
# 31  3290.411330  eJRKHpOXW6_HMaaGIxj1qA
# 32  2199.993026  jQOgTzl68lbBbdgQ-pLnkA
# 33  2241.277120  av0Rz9Yz6Q9N3wqFrwNYLg
# 34  2519.031032  pswO4R6h2emxxakzsCC9sQ
# 35  2484.679906  05E74z_tNUGiMQkI0zsdSQ
# 36  3355.640338  Gp5TNfVx5ilwdfV7unYBew
# 37  3822.768316  Rxu-RIGeG_WPgQ1xjmgE0w
# 38  5141.172240  ZHCu-s7JmHJtUNrgHKePMw
# 39  4498.845276  WJev9IHD54pceaBW6ATvWQ
# 40  4870.978623  08HFmSL8O1JWkiToA7CbBQ
# 41  3900.387418  LJI9yD-_1mNGzC286ymITw
# 42  3748.588653  JJfRYdrnFBRXAhH3at2yKA
# 43  3426.254768  L_VSk1qm6FIWLbBDzCK5Fw
# 44  3436.513458  SZuhoqfawPk-54zQAOitpg
# 45  2460.686936  CmGYC-4AwSg80lwkghLhFA
# 46  4180.754298  n1v10-at-R9gFeTIGx3fEg
# 47  2446.299255  hdSQzmWe3cMd1tUTmCdUIA
# 48  3808.952240  YCDFhTOKJWOvM_z0duxMpA
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/5qapbQ...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/D7f9ox...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/qCb5vz...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/cC_xWa...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/KrjLzF...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/nbmljV...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/w_i41V...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/oFBR1U...      False
# 8                                                          False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/jKcYiq...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/d6QYCL...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/1TsOJs...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/z-2Atl...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/jKtjYV...      False
# 14                                                         False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/8OBfWL...      False
# 16                                                         False
# 17                                                         False
# 18                                                         False
# 19                                                         False
# 20                                                         False
# 21                                                         False
# 22                                                         False
# 23  https://s3-media3.fl.yelpcdn.com/bphoto/y8YEM7...      False
# 24  https://s3-media4.fl.yelpcdn.com/bphoto/TVEbc4...      False
# 25  https://s3-media3.fl.yelpcdn.com/bphoto/mQwruI...      False
# 26                                                         False
# 27                                                         False
# 28                                                         False
# 29  https://s3-media2.fl.yelpcdn.com/bphoto/wCI6-1...      False
# 30  https://s3-media3.fl.yelpcdn.com/bphoto/px3oyD...      False
# 31                                                         False
# 32  https://s3-media4.fl.yelpcdn.com/bphoto/EwJ1fH...      False
# 33                                                         False
# 34  https://s3-media1.fl.yelpcdn.com/bphoto/WZcHsc...      False
# 35                                                         False
# 36                                                         False
# 37  https://s3-media2.fl.yelpcdn.com/bphoto/qOv0iy...      False
# 38  https://s3-media1.fl.yelpcdn.com/bphoto/vWJ1W4...      False
# 39                                                         False
# 40  https://s3-media3.fl.yelpcdn.com/bphoto/9-1ALJ...      False
# 41                                                         False
# 42  https://s3-media3.fl.yelpcdn.com/bphoto/4zcU14...      False
# 43                                                         False
# 44                                                         False
# 45                                                         False
# 46                                                         False
# 47                                                         False
# 48  https://s3-media1.fl.yelpcdn.com/bphoto/nG6Fzm...      False
#
#                                              location  \
# 0   {'address1': '50 Park Terrace', 'address2': No...
# 1   {'address1': '166 Gloucester Street', 'address...
# 2   {'address1': '764 Colombo St', 'address2': '',...
# 3   {'address1': '30 Latimer Square', 'address2': ...
# 4   {'address1': '449 Memorial Ave', 'address2': N...
# 5   {'address1': '28-30 Cathedral Square', 'addres...
# 6   {'address1': '45 Roydvale Ave', 'address2': No...
# 7   {'address1': '189 Deans Ave', 'address2': None...
# 8   {'address1': '859 Colombo Street', 'address2':...
# 9   {'address1': '52 Cathedral Square', 'address2'...
# 10  {'address1': 'Cathedral Square 56', 'address2'...
# 11  {'address1': '7 Kilmarnock St Riccarton', 'add...
# 12  {'address1': '122 Papanui Rd', 'address2': 'Me...
# 13  {'address1': '82 Bealey Ave', 'address2': None...
# 14  {'address1': '306 Riccarton Rd', 'address2': '...
# 15  {'address1': '172 Bealey Avenue', 'address2': ...
# 16  {'address1': '456 Papanui Rd', 'address2': '',...
# 17  {'address1': '166 Riccarton Road', 'address2':...
# 18  {'address1': '38 Riccarton Rd', 'address2': No...
# 19  {'address1': '50 Park Terrace', 'address2': No...
# 20  {'address1': '55 Roydvale Ave', 'address2': No...
# 21  {'address1': '195 Bealey Ave', 'address2': Non...
# 22  {'address1': '168 Yaldhurst Rd', 'address2': '...
# 23  {'address1': '245A Bealey Ave', 'address2': ''...
# 24  {'address1': '302 Bealey Ave', 'address2': Non...
# 25  {'address1': '165 Cashel St', 'address2': '', ...
# 26  {'address1': '42 Papanui Rd', 'address2': None...
# 27  {'address1': '115 Worcester St', 'address2': '...
# 28  {'address1': '17 harry ell Dr', 'address2': No...
# 29  {'address1': '53 Hastings St', 'address2': Non...
# 30  {'address1': '166 Gloucester Street', 'address...
# 31  {'address1': '110 Sherborne St', 'address2': N...
# 32  {'address1': '1 Riccarton Rd', 'address2': Non...
# 33  {'address1': '88-96 Papanui Rd', 'address2': N...
# 34  {'address1': '298 Riccarton Rd', 'address2': '...
# 35  {'address1': '28 Papanui Rd', 'address2': None...
# 36  {'address1': '863 Colombo St', 'address2': Non...
# 37  {'address1': '105 Cashel', 'address2': None, '...
# 38  {'address1': '5 Dinton St', 'address2': '', 'a...
# 39  {'address1': '252 Barbadoes St', 'address2': N...
# 40  {'address1': '550 Memorial Avenue', 'address2'...
# 41  {'address1': '197 Lincoln Rd', 'address2': Non...
# 42  {'address1': '107 Hereford Street', 'address2'...
# 43  {'address1': '168 Bealey Ave', 'address2': Non...
# 44  {'address1': '193 Bealey Ave', 'address2': Non...
# 45  {'address1': '19 Bealey Ave', 'address2': None...
# 46  {'address1': '140 Lincoln Rd', 'address2': '',...
# 47  {'address1': '280 Riccarton Rd', 'address2': '...
# 48  {'address1': '113 Worchester', 'address2': Non...
#
#                                                  name          phone price  \
# 0                                          The George    +6433794560   $$$
# 1                       Rendezvous Hotel Christchurch    +6439433888    $$
# 2                     Crowne Plaza Hotel Christchurch  +646437412800    $$
# 3                         Rydges Latimer Christchurch    +6433796760   $$$
# 4                           Copthorne Hotel Commodore    +6433588129    $$
# 5                               Heritage Christchurch    +6439834800    $$
# 6                         Airport Gateway Motor Lodge    +6433587093    $$
# 7   Chateau on the Park - Christchurch, a DoubleTr...    +6433488999   $$$
# 8                              Centrepoint On Colombo    +6433770859    $$
# 9                                Novotel Christchurch   +64643722111   $$$
# 10                             ChristChurch Cathedral    +6433634420     $
# 11                         Quality Towers On The Park    +6433441977   $$$
# 12                                     Merivale Manor    +6433557731    $$
# 13                       Eliza's Manor Boutique Hotel    +6433668584    $$
# 14                             306 on Riccarton Motel  +646433434306   NaN
# 15                                  Belmont Motor Inn    +6433794037   NaN
# 16                                 Quality Hotel Elms  +646433553577    $$
# 17                           166 Majestic Court Motel    +6439828162   NaN
# 18                            Roma On Riccarton Motel    +6433411189   NaN
# 19                                   The George Hotel    +6433794560   NaN
# 20                         Airport Christchurch Motel    +6439774970   NaN
# 21                                       Home Lea B&B    +6433799977   NaN
# 22                              Avonhead Garden Motel   +64800805010   NaN
# 23                       Canterbury House Backpackers    +6433778108   NaN
# 24                                        Aotea Motel    +6433777188    $$
# 25                                Breakfree On Cashel   +64800448891    $$
# 26                       Pavilions Hotel Christchurch    +6433555633   $$$
# 27                                          Hotel 115                   $$
# 28                              Pacific View Paradise    +6433326992    $$
# 29                                   Designer Cottage    +6433778088    $$
# 30                                   Rendezvous Hotel    +6439433888    $$
# 31                         Arthur's Court Motor Lodge    +6433669085    $$
# 32                                 Parkview On Hagley                   $$
# 33                           Heartland Hotel Cotswold    +6433553535    $$
# 34                  Westside Motor Lodge Christchurch    +6433417254   NaN
# 35                                Camelot Motor Lodge    +6433559124    $$
# 36                                Colombo In The City    +6433655378   NaN
# 37                                       Boatshed Bar    +6433650859     $
# 38                                      Airways Motel    +6433429464   NaN
# 39                      City Central Motel Apartments    +6433790540    $$
# 40                  Sudima Hotel Christchurch Airport                  NaN
# 41                              Addington Court Motel    +6433394211   NaN
# 42                            Ibis Christchurch Hotel    +6433678666    $$
# 43                                      Admiral Motel    +6433793554   NaN
# 44                     Bella Vista Motel Christchurch    +6433773363   NaN
# 45                         Comfort Hotel Carlton Mill                    $
# 46                       Econo Lodge Canterbury Court  +646433388351   NaN
# 47                              Comfort Inn Riccarton  +646433411280   NaN
# 48                      Quest Apartments Christchurch                  NaN
#
#     rating  review_count transactions  \
# 0      5.0             9           []
# 1      4.5             4           []
# 2      4.5             5           []
# 3      3.5             6           []
# 4      4.0             5           []
# 5      5.0             2           []
# 6      4.5             3           []
# 7      3.0             5           []
# 8      5.0             2           []
# 9      4.0             4           []
# 10     3.5             3           []
# 11     4.0             2           []
# 12     5.0             1           []
# 13     5.0             1           []
# 14     4.5             2           []
# 15     5.0             1           []
# 16     5.0             1           []
# 17     5.0             1           []
# 18     5.0             1           []
# 19     5.0             1           []
# 20     5.0             1           []
# 21     5.0             1           []
# 22     5.0             1           []
# 23     5.0             1           []
# 24     5.0             1           []
# 25     3.5             3           []
# 26     3.0             3           []
# 27     3.0             3           []
# 28     5.0             1           []
# 29     5.0             2           []
# 30     2.5             3           []
# 31     4.0             2           []
# 32     4.0             1           []
# 33     3.0             2           []
# 34     4.0             1           []
# 35     4.0             1           []
# 36     4.0             1           []
# 37     4.0             1           []
# 38     4.0             1           []
# 39     4.0             1           []
# 40     2.5             2           []
# 41     4.0             1           []
# 42     2.0             1           []
# 43     5.0             1           []
# 44     5.0             1           []
# 45     2.0             1           []
# 46     4.0             1           []
# 47     2.0             1           []
# 48     1.0             1           []
#
#                                                   url
# 0   https://www.yelp.com/biz/the-george-christchur...
# 1   https://www.yelp.com/biz/rendezvous-hotel-chri...
# 2   https://www.yelp.com/biz/crowne-plaza-hotel-ch...
# 3   https://www.yelp.com/biz/rydges-latimer-christ...
# 4   https://www.yelp.com/biz/copthorne-hotel-commo...
# 5   https://www.yelp.com/biz/heritage-christchurch...
# 6   https://www.yelp.com/biz/airport-gateway-motor...
# 7   https://www.yelp.com/biz/chateau-on-the-park-c...
# 8   https://www.yelp.com/biz/centrepoint-on-colomb...
# 9   https://www.yelp.com/biz/novotel-christchurch-...
# 10  https://www.yelp.com/biz/christchurch-cathedra...
# 11  https://www.yelp.com/biz/quality-towers-on-the...
# 12  https://www.yelp.com/biz/merivale-manor-christ...
# 13  https://www.yelp.com/biz/elizas-manor-boutique...
# 14  https://www.yelp.com/biz/306-on-riccarton-mote...
# 15  https://www.yelp.com/biz/belmont-motor-inn-chr...
# 16  https://www.yelp.com/biz/quality-hotel-elms-ch...
# 17  https://www.yelp.com/biz/166-majestic-court-mo...
# 18  https://www.yelp.com/biz/roma-on-riccarton-mot...
# 19  https://www.yelp.com/biz/the-george-hotel-chri...
# 20  https://www.yelp.com/biz/airport-christchurch-...
# 21  https://www.yelp.com/biz/home-lea-b-and-b-chri...
# 22  https://www.yelp.com/biz/avonhead-garden-motel...
# 23  https://www.yelp.com/biz/canterbury-house-back...
# 24  https://www.yelp.com/biz/aotea-motel-christchu...
# 25  https://www.yelp.com/biz/breakfree-on-cashel-c...
# 26  https://www.yelp.com/biz/pavilions-hotel-chris...
# 27  https://www.yelp.com/biz/hotel-115-christchurc...
# 28  https://www.yelp.com/biz/pacific-view-paradise...
# 29  https://www.yelp.com/biz/designer-cottage-chri...
# 30  https://www.yelp.com/biz/rendezvous-hotel-chri...
# 31  https://www.yelp.com/biz/arthurs-court-motor-l...
# 32  https://www.yelp.com/biz/parkview-on-hagley-ch...
# 33  https://www.yelp.com/biz/heartland-hotel-cotsw...
# 34  https://www.yelp.com/biz/westside-motor-lodge-...
# 35  https://www.yelp.com/biz/camelot-motor-lodge-c...
# 36  https://www.yelp.com/biz/colombo-in-the-city-c...
# 37  https://www.yelp.com/biz/boatshed-bar-christch...
# 38  https://www.yelp.com/biz/airways-motel-christc...
# 39  https://www.yelp.com/biz/city-central-motel-ap...
# 40  https://www.yelp.com/biz/sudima-hotel-christch...
# 41  https://www.yelp.com/biz/addington-court-motel...
# 42  https://www.yelp.com/biz/ibis-christchurch-hot...
# 43  https://www.yelp.com/biz/admiral-motel-christc...
# 44  https://www.yelp.com/biz/bella-vista-motel-chr...
# 45  https://www.yelp.com/biz/comfort-hotel-carlton...
# 46  https://www.yelp.com/biz/econo-lodge-canterbur...
# 47  https://www.yelp.com/biz/comfort-inn-riccarton...
# 48  https://www.yelp.com/biz/quest-apartments-chri...
